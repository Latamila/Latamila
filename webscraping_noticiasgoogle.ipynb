# %% [markdown]
# <a href="https://colab.research.google.com/github/Latamila/Latamila/blob/main/webscraping_noticiasgoogle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #AULA WEBSCRAPING DA UNIVESP DO YOUTUBE PARA DATA SCIENCE

# %% [markdown]
# USO DO BEAUTIFULSOUP

# %%
import urllib.request

# %%
from urllib.request import urlopen as uReq

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
html=requests.get("https://www.google.com/search?q=noticias+AND+avia%C3%A7%C3%A3o+AND+aeroportos+AND+brasil&sxsrf=ALiCzsaot7eQwk47byA6EfAoQv96-5KD3w:1665407574723&source=lnt&tbs=qdr:d&sa=X&ved=2ahUKEwjM5pbX3tX6AhWFCdQKHZoWC_QQpwV6BAgBEBs&biw=1536&bih=718&dpr=1.25")

# %%
html
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(html.text,'html.parser')

# %%
soup.head
# Out:
# <head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>noticias AND aviação AND aeroportos AND brasil - Google Search</title><script nonce="bexMCMgLM_b6HmqczlMwSQ">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
soup.title#aqui mostra como a busca foi feita no google
# Out:
# <title>noticias AND aviação AND aeroportos AND brasil - Google Search</title>

# %%
#head_tag = soup.head

# %%
#head_tag.contents

# %%
#title_tag = head_tag.contents[3]

# %%
#title_tag

# %%
for child in soup.title.children:
    print(child)
# Out:
# noticias AND aviação AND aeroportos AND brasil - Google Search

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    noticias AND aviação AND aeroportos AND brasil - Google Search
#   </title>
#   <script nonce="bexMCMgLM_b6HmqczlMwSQ">
#    (function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
todos_links=soup.find_all('a')
todos_links
# Out:
# [<a href="/?sa=X&amp;ved=0ahUKEwjcro6z39X6AhUWVTABHXsgDAsQOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a>,
#  <a href="/search?q=noticias+AND+avia%C3%A7%C3%A3o+AND+aeroportos+AND+brasil&amp;tbs=qdr:d&amp;sa=X&amp;biw=1536&amp;bih=718&amp;ie=UTF-8&amp;gbv=1&amp;sei=FxtEY5zHH5aqwbkP-8CwWA">here</a>,
#  <a class="eZt8xd" href="/search?q=noticias+AND+avia%C3%A7%C3%A3o+AND+aeroportos+AND+brasil&amp;biw=1536&amp;bih=718&amp;ie=UTF-8&amp;source=lnms&amp;tbm=nws&amp;tbs=qdr:d&amp;sa=X&amp;ved=0ahUKEwjcro6z39X6AhUWVTABHXsgDAsQ_AUIBigB">News</a>,
#  <a class="eZt8xd" href="/search?q=noticias+AND+avia%C3%A7%C3%A3o+AND+aeroportos+AND+brasil&amp;biw=1536&amp;bih=718&amp;ie=UTF-8&amp;source=lnms&amp;tbm=isch&amp;tbs=qdr:d&amp;sa=X&amp;ved=0ahUKEwjcro6z39X6AhUWVTABHXsgDAsQ_AUIBygC">Images</a>,
# ...

# %%
todos_links[0]
# Out:
# <a href="/?sa=X&amp;ved=0ahUKEwjcro6z39X6AhUWVTABHXsgDAsQOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a>

# %%
titulos = soup.find_all('h3')

# %%
noticias=[]
for row in titulos:
  dado=row.find_all('div')
  noticias.append(dado[0].text)
print(noticias)
# Out:
# ['Pneu estoura e avião para rente a barranco do fim da pista do ... - G1', 'Aeroporto de Congonhas é liberado após quase 9 horas e voos são ...', 'Viagens aéreas precisam ser mais acessíveis no Brasil, diz ...', 'AEROIN | Notícias de Aviação', 'Viagens aéreas precisam ficar mais baratas no Brasil, diz Iata - GZH', 'Avião é retirado da pista, e operação do Aeroporto de Congonhas é ...', 'Congonhas fecha pista após estouro de pneu de avião - 09/10/2022', 'Aeroporto de Congonhas cancela mais de 70 voos após avião sair ...', 'Pneu de avião estoura durante pouso em Aeroporto de Congonhas', 'Operações no Aeroporto de Congonhas são liberadas após acidente']

# %%
for i in range(len(noticias)):
  print(noticias[i])
# Out:
# Pneu estoura e avião para rente a barranco do fim da pista do ... - G1
# Aeroporto de Congonhas é liberado após quase 9 horas e voos são ...
# Viagens aéreas precisam ser mais acessíveis no Brasil, diz ...
# AEROIN | Notícias de Aviação
# Viagens aéreas precisam ficar mais baratas no Brasil, diz Iata - GZH
# Avião é retirado da pista, e operação do Aeroporto de Congonhas é ...
# Congonhas fecha pista após estouro de pneu de avião - 09/10/2022
# Aeroporto de Congonhas cancela mais de 70 voos após avião sair ...
# Pneu de avião estoura durante pouso em Aeroporto de Congonhas
# Operações no Aeroporto de Congonhas são liberadas após acidente

# %%
dados=pd.DataFrame(noticias, columns=['noticias'])
dados #busquei dados a partir da inspeção do html, ferramenta de mineração de dados.
# Out:
#                                             noticias
# 0  Pneu estoura e avião para rente a barranco do ...
# 1  Aeroporto de Congonhas é liberado após quase 9...
# 2  Viagens aéreas precisam ser mais acessíveis no...
# 3                       AEROIN | Notícias de Aviação
# 4  Viagens aéreas precisam ficar mais baratas no ...
# 5  Avião é retirado da pista, e operação do Aerop...
# 6  Congonhas fecha pista após estouro de pneu de ...
# 7  Aeroporto de Congonhas cancela mais de 70 voos...
# 8  Pneu de avião estoura durante pouso em Aeropor...
# 9  Operações no Aeroporto de Congonhas são libera...

# %% [markdown]
# AGORA NO MOMENTO ESTOU COPIANDO OS LINKS E AGREGANDO EM UM GOOGLE DOCS
